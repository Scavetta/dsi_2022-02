# %%
# import the enecessary libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
cars = pd.read_csv("../00-data/cars1.csv")

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           198 non-null    float64
#  1   cylinders     198 non-null    int64
#  2   displacement  198 non-null    int64
#  3   horsepower    198 non-null    object
#  4   weight        198 non-null    int64
#  5   acceleration  198 non-null    float64
#  6   model         198 non-null    int64
#  7   origin        198 non-null    int64
#  8   car           198 non-null    object
#  9   Unnamed: 9    0 non-null      float64
#  10  Unnamed: 10   0 non-null      float64
#  11  Unnamed: 11   0 non-null      float64
#  12  Unnamed: 12   0 non-null      float64
#  13  Unnamed: 13   0 non-null      float64
# dtypes: float64(7), int64(5), object(2)
# memory usage: 21.8+ KB

# %%
cars.dropna(axis =1, how = "all", inplace=True)

# %%
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %%
cars[['mpg', 'cylinders']]
# Out:
#       mpg  cylinders
# 0    18.0          8
# 1    15.0          8
# 2    18.0          8
# 3    16.0          8
# 4    17.0          8
# ..    ...        ...
# 193  24.0          6
# 194  22.5          6
# 195  29.0          4
# 196  24.5          4
# 197  29.0          4
#
# [198 rows x 2 columns]

# %%
cars.loc[194, "mpg"]
# Out:
# 22.5

# %%
# dataframe.iloc[rows, columns (start:finish)]
cars.iloc[:2, 0:-1]
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
#
#    origin
# 0       1
# 1       1

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           198 non-null    float64
#  1   cylinders     198 non-null    int64
#  2   displacement  198 non-null    int64
#  3   horsepower    198 non-null    object
#  4   weight        198 non-null    int64
#  5   acceleration  198 non-null    float64
#  6   model         198 non-null    int64
#  7   origin        198 non-null    int64
#  8   car           198 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 14.0+ KB

# %%
cars.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement      int64
# horsepower       object
# weight            int64
# acceleration    float64
# model             int64
# origin            int64
# car              object
# dtype: object

# %%
def catch(a):
    try:
        return float(a)
    except:
        print(f"error at value {a}")
        return None

# %%
cars["hp_2"] = cars['horsepower'].map(catch)
# Out:
# error at value ?
# error at value ?

# %%
cars.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model           0
# origin          0
# car             0
# hp_2            2
# dtype: int64

# %%
cars[cars["horsepower"] == "?"]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 32   25.0          4            98          ?    2046          19.0     71
# 126  21.0          6           200          ?    2875          17.0     74
#
#      origin            car
# 32        1     ford pinto
# 126       1  ford maverick

# %%
cars[cars.car == "ford pinto"]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 32   25.0          4            98          ?    2046          19.0     71
# 112  19.0          4           122         85    2310          18.5     73
# 130  26.0          4           122         80    2451          16.5     74
# 168  23.0          4           140         83    2639          17.0     75
# 174  18.0          6           171         97    2984          14.5     75
#
#      origin         car
# 32        1  ford pinto
# 112       1  ford pinto
# 130       1  ford pinto
# 168       1  ford pinto
# 174       1  ford pinto

# %%
cars[cars.car == "ford maverick"]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 17   21.0          6           200         85    2587          16.0     70
# 100  18.0          6           250         88    3021          16.5     73
# 126  21.0          6           200          ?    2875          17.0     74
# 155  15.0          6           250         72    3158          19.5     75
# 193  24.0          6           200         81    3012          17.6     76
#
#      origin            car
# 17        1  ford maverick
# 100       1  ford maverick
# 126       1  ford maverick
# 155       1  ford maverick
# 193       1  ford maverick

# %%
cars['hp_2'].mean()
# Out:
# 116.24489795918367

# %%
# After research, in 1971 a ford pinto models were manufactured matching theo the info we have (cylinders and discplacemnt)
#  75 hp

# For ford maverick 75 hp

# %%
cars.hp_2.fillna(75.0, inplace=True)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           198 non-null    float64
#  1   cylinders     198 non-null    int64
#  2   displacement  198 non-null    int64
#  3   horsepower    198 non-null    object
#  4   weight        198 non-null    int64
#  5   acceleration  198 non-null    float64
#  6   model         198 non-null    int64
#  7   origin        198 non-null    int64
#  8   car           198 non-null    object
#  9   hp_2          198 non-null    float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 15.6+ KB

# %%
cars.drop("horsepower", axis=1, inplace=True)

# %%
cars.rename({"hp_2":"horsepower"}, axis=1, inplace=True)

# %%
cars
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 0    18.0          8           307    3504          12.0     70       1
# 1    15.0          8           350    3693          11.5     70       1
# 2    18.0          8           318    3436          11.0     70       1
# 3    16.0          8           304    3433          12.0     70       1
# 4    17.0          8           302    3449          10.5     70       1
# ..    ...        ...           ...     ...           ...    ...     ...
# 193  24.0          6           200    3012          17.6     76       1
# 194  22.5          6           232    3085          17.6     76       1
# 195  29.0          4            85    2035          22.2     76       1
# 196  24.5          4            98    2164          22.1     76       1
# 197  29.0          4            90    1937          14.2     76       2
#
#                            car  horsepower
# 0    chevrolet chevelle malibu       130.0
# ...

# %%
cars.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement      int64
# weight            int64
# acceleration    float64
# model             int64
# origin            int64
# car              object
# horsepower      float64
# dtype: object

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 0  18.0          8           307    3504          12.0     70       1
# 1  15.0          8           350    3693          11.5     70       1
# 2  18.0          8           318    3436          11.0     70       1
# 3  16.0          8           304    3433          12.0     70       1
# 4  17.0          8           302    3449          10.5     70       1
#
#                          car  horsepower
# 0  chevrolet chevelle malibu       130.0
# 1          buick skylark 320       165.0
# 2         plymouth satellite       150.0
# 3              amc rebel sst       150.0
# 4                ford torino       140.0

# %%
cars.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  198.000000  198.000000    198.000000   198.000000    198.000000
# mean    19.719697    5.898990    223.469697  3177.888889     15.005556
# std      5.814254    1.785417    115.181017   934.783733      2.872382
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     15.000000    4.000000    113.250000  2302.500000     13.000000
# 50%     19.000000    6.000000    228.000000  3030.000000     15.000000
# 75%     24.375000    8.000000    318.000000  4080.750000     16.800000
# max     35.000000    8.000000    455.000000  5140.000000     23.500000
#
#             model      origin  horsepower
# count  198.000000  198.000000  198.000000
# mean    72.818182    1.439394  115.828283
# std      1.865332    0.708085   43.589814
# min     70.000000    1.000000   46.000000
# 25%     71.000000    1.000000   86.000000
# 50%     73.000000    1.000000  100.000000
# ...

# %%
import pandas as pd
cars = pd.read_csv("../00-data/cars1.csv")

# 1- What is the lightest and heaviest car (row number and car name)
# 2- What is the oldest car
# 3- which one has the fastest acceleration
# 4- which car is the most powerful
## ** bonus: do not use the actual values from the describe table above, instead use min/max methods

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 0  18.0          8           307    3504          12.0     70       1
# 1  15.0          8           350    3693          11.5     70       1
# 2  18.0          8           318    3436          11.0     70       1
# 3  16.0          8           304    3433          12.0     70       1
# 4  17.0          8           302    3449          10.5     70       1
#
#                          car  horsepower
# 0  chevrolet chevelle malibu       130.0
# 1          buick skylark 320       165.0
# 2         plymouth satellite       150.0
# 3              amc rebel sst       150.0
# 4                ford torino       140.0

# %%
cars[cars.weight == cars.weight.max()]
# Out:
#      mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 44  13.0          8           400    5140          12.0     71       1
#
#                     car  horsepower
# 44  pontiac safari (sw)       175.0

# %%
cars[cars.weight == cars.weight.min()]
# Out:
#      mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 54  35.0          4            72    1613          18.0     71       3
#
#             car  horsepower
# 54  datsun 1200        69.0

# %%
cars[cars.model == cars.model.min()]
# Out:
#      mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 0   18.0          8           307    3504          12.0     70       1
# 1   15.0          8           350    3693          11.5     70       1
# 2   18.0          8           318    3436          11.0     70       1
# 3   16.0          8           304    3433          12.0     70       1
# 4   17.0          8           302    3449          10.5     70       1
# 5   15.0          8           429    4341          10.0     70       1
# 6   14.0          8           454    4354           9.0     70       1
# 7   14.0          8           440    4312           8.5     70       1
# 8   14.0          8           455    4425          10.0     70       1
# 9   15.0          8           390    3850           8.5     70       1
# 10  15.0          8           383    3563          10.0     70       1
# 11  14.0          8           340    3609           8.0     70       1
# ...

# %%
# Bonus exercise
# Instead of repeating the same code command above, write a fucntion taht takes the dataframe,
# the feature, and returns the car(s) wwith the minimum and maximum vales

# %%
cars.cylinders.value_counts()
# Out:
# 4    80
# 8    73
# 6    43
# 3     2
# Name: cylinders, dtype: int64

# %%
def to_kg(x):
    return round(x/2.2)

# %%
# To convert 1 lb  = 1/2.2 kg
cars["weight_kg"] = cars.weight.map(to_kg)

# %%
cars.drop("wight_kg", axis=1, inplace=True)

# %%
cars
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 0    18.0          8           307    3504          12.0     70       1
# 1    15.0          8           350    3693          11.5     70       1
# 2    18.0          8           318    3436          11.0     70       1
# 3    16.0          8           304    3433          12.0     70       1
# 4    17.0          8           302    3449          10.5     70       1
# ..    ...        ...           ...     ...           ...    ...     ...
# 193  24.0          6           200    3012          17.6     76       1
# 194  22.5          6           232    3085          17.6     76       1
# 195  29.0          4            85    2035          22.2     76       1
# 196  24.5          4            98    2164          22.1     76       1
# 197  29.0          4            90    1937          14.2     76       2
#
#                            car  horsepower  weight_kg
# ...

# %%
cars.weight_kg.plot.hist();

# %%
def is_heavy(x):
    if x > 1800:
        result = "heavy"
    elif x > 1200:
        result = "medium"
    else:
        result = "light"
    return result

# %%
cars["is_heavy"] = cars.weight_kg.apply(is_heavy)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 0  18.0          8           307    3504          12.0     70       1
# 1  15.0          8           350    3693          11.5     70       1
# 2  18.0          8           318    3436          11.0     70       1
# 3  16.0          8           304    3433          12.0     70       1
# 4  17.0          8           302    3449          10.5     70       1
#
#                          car  horsepower  weight_kg is_heavy
# 0  chevrolet chevelle malibu       130.0       1593   medium
# 1          buick skylark 320       165.0       1679   medium
# 2         plymouth satellite       150.0       1562   medium
# 3              amc rebel sst       150.0       1560   medium
# 4                ford torino       140.0       1568   medium

# %%
cars.is_heavy.value_counts()
# Out:
# light     75
# medium    69
# heavy     54
# Name: is_heavy, dtype: int64

# %%
# new columns that calculates ration of weight and acceleration

# %%
def ratio(df):
    return df["weight"]/df['acceleration']

# %%
cars['new_col'] = cars['weight']/cars['acceleration']

# %%
cars.apply(ratio, axis=1)
# Out:
# 0      292.000000
# 1      321.130435
# 2      312.363636
# 3      286.083333
# 4      328.476190
#           ...
# 193    171.136364
# 194    175.284091
# 195     91.666667
# 196     97.918552
# 197    136.408451
# Length: 198, dtype: float64

# %%
cars['model'] = cars.model.map(lambda x:x+1900)

# %%
cars
# Out:
#       mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 0    18.0          8           307    3504          12.0   1970       1
# 1    15.0          8           350    3693          11.5   1970       1
# 2    18.0          8           318    3436          11.0   1970       1
# 3    16.0          8           304    3433          12.0   1970       1
# 4    17.0          8           302    3449          10.5   1970       1
# ..    ...        ...           ...     ...           ...    ...     ...
# 193  24.0          6           200    3012          17.6   1976       1
# 194  22.5          6           232    3085          17.6   1976       1
# 195  29.0          4            85    2035          22.2   1976       1
# 196  24.5          4            98    2164          22.1   1976       1
# 197  29.0          4            90    1937          14.2   1976       2
#
#                            car  horsepower  weight_kg is_heavy
# ...

# %%
# Create a new column with the cars make (brand name)

def carname(a):
    return a.split()[0]

# %%
carname("ford pinto")
# Out:
# 'ford'

# %%
cars['make'] = cars.car.map(lambda x:x.split()[0])

# %%
cars["make"] = cars.car.map(carname)

# %%
cars.head()
# Out:
#     mpg  cylinders  displacement  weight  acceleration  model  origin  \
# 0  18.0          8           307    3504          12.0   1970       1
# 1  15.0          8           350    3693          11.5   1970       1
# 2  18.0          8           318    3436          11.0   1970       1
# 3  16.0          8           304    3433          12.0   1970       1
# 4  17.0          8           302    3449          10.5   1970       1
#
#                          car  horsepower  weight_kg is_heavy       make
# 0  chevrolet chevelle malibu       130.0       1593   medium  chevrolet
# 1          buick skylark 320       165.0       1679   medium      buick
# 2         plymouth satellite       150.0       1562   medium   plymouth
# 3              amc rebel sst       150.0       1560   medium        amc
# 4                ford torino       140.0       1568   medium       ford

# %%
cars.make.unique
# Out:
# <bound method Series.unique of 0      chevrolet
# 1          buick
# 2       plymouth
# 3            amc
# 4           ford
#          ...
# 193         ford
# 194          amc
# 195    chevrolet
# 196    chevrolet
# 197           vw
# Name: make, Length: 198, dtype: object>

# %%
cars.make.value_counts()
# Out:
# ford          29
# chevrolet     26
# amc           21
# plymouth      19
# dodge         11
# toyota        11
# volkswagen     8
# buick          8
# datsun         8
# pontiac        8
# fiat           7
# mercury        5
# opel           4
# peugeot        4
# audi           4
# volvo          3
# oldsmobile     3
# saab           3
# chrysler       2
# renault        2
# honda          2
# chevroelt      1
# capri          1
# subaru         1
# maxda          1
# hi             1
# toyouta        1
# mazda          1
# chevy          1
# bmw            1
# vw             1
# Name: make, dtype: int64
